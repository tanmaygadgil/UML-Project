# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **Note:** Please make sure you have the prerequisites installed for each of these codes

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import nltk
from nltk import FreqDist
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tanma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
# pd.set_option("display.max_colwidth", 200)
import numpy as np
import json
import re
import gzip
import spacy

import gensim
from gensim import corpora
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords

import nltk

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer

from nltk.stem import WordNetLemmatizer

from tqdm import tqdm

# %%
review_df = pd.read_csv('./data/reviews.csv')
review_df.drop(columns=['Unnamed: 0'], inplace= True)

# %%
review_df['review_text'].fillna('', inplace = True)

# %%
book_df = pd.read_csv("./data/top_1000_books.csv")
book_df.drop(columns=['Unnamed: 0'], inplace= True)

# %%
review_df.head()
# Out:
#    book_id                           user_id  \
# 0     5805  6baf45d03466a5858403d892286ff222
# 1     5805  76413aa32ae6debd29ff7c2c437f17ca
# 2     5805  c001efe2d798df0bbac0ba51dbed1f9b
# 3     5805  2d43e0a1f7e9c0946fdf7f71fddbf7a8
# 4     5805  d6804aa6e3a96b8e1104b8b9ac3fe882
#
#                           review_id  rating  \
# 0  8d680b828c9b260423f5740e67b03291       4
# 1  80a09e6153378edbe685b640b1b957f0       4
# 2  65715d42615cf1ca8c7151bd25a22544       3
# 3  d55a8c7950191477cf62cc76677bbf19       2
# 4  77ad3c07806bb88c5a1bfa46b9357b20       3
#
#                                          review_text  \
# 0    Could use less misogyny and stockholm syndrome.
# 1  I love the artwork. I love the ideas that V re...
# 2  interesting graphic novel. Interesting created...
# 3  Honestly, I was really disappointed by this. O...
# 4  I enjoyed this book---and the idea of a "Robin...
#
#                        date_added                    date_updated  \
# 0  Thu Apr 21 11:27:06 -0700 2016  Thu Apr 21 11:27:36 -0700 2016
# 1  Tue Nov 18 09:14:16 -0800 2014  Sun Dec 21 16:14:29 -0800 2014
# 2  Sun Sep 07 12:35:48 -0700 2008  Sun Sep 07 12:39:38 -0700 2008
# 3  Sun Jun 10 11:07:52 -0700 2012  Sat Jan 30 11:14:07 -0800 2016
# 4  Sat Jan 09 18:46:54 -0800 2010  Sun Jan 17 18:24:13 -0800 2010
#
#                           read_at                      started_at  n_votes  \
# 0  Thu Apr 21 11:27:36 -0700 2016                             NaN        0
# 1  Sun Dec 21 00:00:00 -0800 2014  Tue Nov 18 00:00:00 -0800 2014        0
# 2  Sun Sep 07 00:00:00 -0700 2008                             NaN        0
# 3  Sat Jan 01 00:00:00 -0800 2011                             NaN        0
# 4  Sat Jan 16 00:00:00 -0800 2010                             NaN        0
#
#    n_comments
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
engaged_df = review_df[(review_df['n_votes'] > 0)|(review_df['n_comments'] > 0)]

# %%
engaged_df.head()
# Out:
#     book_id                           user_id  \
# 6      5805  4cbecbc15af3db041a8e0f594c642bb5
# 8      5805  49cc59f1c479d698507627b401d47ecf
# 10     5805  5f03864c758bfceb6d7d5e93eeb20044
# 12     5805  c309dff1695ed8558b29ea8dcd7479b8
# 13     5805  0f6b8c04f811e05c8978bd6b66ce7685
#
#                            review_id  rating  \
# 6   58f2301bd2d4bbfc1b51e4e5fb161cfe       5
# 8   761a17f52538341a085b629a316204a1       4
# 10  ac54c3ce0c9f660c03881b0668f79c60       5
# 12  0da0bcc469c2acd15350f9a8f0a74e2b       5
# 13  7d670b6c8cac0c086e21ae2f1af6eccb       4
#
#                                           review_text  \
# 6   Remember, remember, the fifth of November. Thi...
# 8   Tinha apontado este livro como um dos que tinh...
# 10      Review coming soon! www.youtube.com/ReadTomes
# 12  What better way to celebrate Guy Fawkes Day, t...
# 13  To note - I am writing this review a quarter c...
#
#                         date_added                    date_updated  \
# 6   Wed Jun 13 17:55:53 -0700 2012  Mon Jan 30 05:58:01 -0800 2017
# 8   Sun Jan 05 03:27:10 -0800 2014  Tue Oct 28 15:58:20 -0700 2014
# 10  Tue Feb 12 11:38:36 -0800 2013  Tue Feb 12 12:00:47 -0800 2013
# 12  Tue May 20 09:52:36 -0700 2014  Thu Mar 16 09:49:11 -0700 2017
# 13  Tue Jul 03 16:43:26 -0700 2012  Fri Feb 27 14:46:00 -0800 2015
#
#                            read_at                      started_at  n_votes  \
# 6   Thu Jun 14 00:00:00 -0700 2012                             NaN        7
# 8   Tue Oct 28 15:58:20 -0700 2014                             NaN        1
# 10  Tue Feb 12 12:00:47 -0800 2013  Tue Feb 12 00:00:00 -0800 2013        1
# 12  Wed Nov 05 14:22:10 -0800 2014  Wed Nov 05 00:00:00 -0800 2014        2
# 13  Tue Jan 01 00:00:00 -0800 1991                             NaN       10
#
#     n_comments
# 6            0
# 8            0
# 10           0
# 12           0
# 13           0

# %%
lm  = WordNetLemmatizer()

# %%
stop_words = set(stopwords.words('english'))

# %%
words = set(nltk.corpus.words.words())

# %%
# nlp = spacy.load('en', disable=['parser', 'ner'])
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def preprocess(x):
    try:
        x = re.sub("n\'t", " not", x)
        x = re.sub("\'d", " would", x)
        x = re.sub("[^a-zA-Z0-9#]", " ", x)
        x = re.sub("www", " ", x)
        x = re.sub("http", " ", x)
        x = re.sub("https", " ", x)
        x = re.sub("com", " ", x)
        x = re.sub("url", " ", x)
        return x
    except:
        print(x)
        return ""

# %%
def lemmas(x, lm, tags=['NOUN', 'ADJ']):
    x = word_tokenize(x)
    
    x = [lm.lemmatize(w).lower() for w in x]
    
#     print(x)
    x = nlp(" ".join(x))
#     x = [w for w in x if w in words]
    x = [token.lemma_ for token in x if token.pos_ in tags or token.lemma_ in words]
    x = [w for w in x if not w.lower() in stop_words]
    x = [w for w in x if len(w) > 2]
    
    return x

# %%
engaged_df['clean_reviews'] = engaged_df['review_text'].apply(lambda x: preprocess(x))

# %%
engaged_df['clean_reviews'] = engaged_df['clean_reviews'].apply(lambda x: lemmas(x, lm))

# %%
engaged_df.head()
# Out:
#     book_id                           user_id  \
# 6      5805  4cbecbc15af3db041a8e0f594c642bb5
# 8      5805  49cc59f1c479d698507627b401d47ecf
# 10     5805  5f03864c758bfceb6d7d5e93eeb20044
# 12     5805  c309dff1695ed8558b29ea8dcd7479b8
# 13     5805  0f6b8c04f811e05c8978bd6b66ce7685
#
#                            review_id  rating  \
# 6   58f2301bd2d4bbfc1b51e4e5fb161cfe       5
# 8   761a17f52538341a085b629a316204a1       4
# 10  ac54c3ce0c9f660c03881b0668f79c60       5
# 12  0da0bcc469c2acd15350f9a8f0a74e2b       5
# 13  7d670b6c8cac0c086e21ae2f1af6eccb       4
#
#                                           review_text  \
# 6   Remember, remember, the fifth of November. Thi...
# 8   Tinha apontado este livro como um dos que tinh...
# 10      Review coming soon! www.youtube.com/ReadTomes
# 12  What better way to celebrate Guy Fawkes Day, t...
# 13  To note - I am writing this review a quarter c...
#
#                         date_added                    date_updated  \
# 6   Wed Jun 13 17:55:53 -0700 2012  Mon Jan 30 05:58:01 -0800 2017
# 8   Sun Jan 05 03:27:10 -0800 2014  Tue Oct 28 15:58:20 -0700 2014
# 10  Tue Feb 12 11:38:36 -0800 2013  Tue Feb 12 12:00:47 -0800 2013
# 12  Tue May 20 09:52:36 -0700 2014  Thu Mar 16 09:49:11 -0700 2017
# 13  Tue Jul 03 16:43:26 -0700 2012  Fri Feb 27 14:46:00 -0800 2015
#
#                            read_at                      started_at  n_votes  \
# 6   Thu Jun 14 00:00:00 -0700 2012                             NaN        7
# 8   Tue Oct 28 15:58:20 -0700 2014                             NaN        1
# 10  Tue Feb 12 12:00:47 -0800 2013  Tue Feb 12 00:00:00 -0800 2013        1
# 12  Wed Nov 05 14:22:10 -0800 2014  Wed Nov 05 00:00:00 -0800 2014        2
# 13  Tue Jan 01 00:00:00 -0800 1991                             NaN       10
#
#     n_comments                                      clean_reviews
# 6            0  [remember, remember, fifth, part, quote, origi...
# 8            0  [tinha, visto, portman, hora, livro, tinha, ge...
# 10           0                      [review, ing, soon, readtome]
# 12           0  [well, way, celebrate, guy, day, read, modern,...
# 13           0  [note, write, review, quarter, century, read, ...

# %%
engaged_df.to_csv('./data/engaged_df.csv', index = False)

# %%
dictionary = corpora.Dictionary(engaged_df['clean_reviews'])

# %%
doc_term_matrix = tqdm([dictionary.doc2bow(rev) for rev in engaged_df['clean_reviews']])
# Out:
#   0%|                                                                                        | 0/39787 [00:00<?, ?it/s]

# %% [markdown]
# ### preprocessing the book df for the description data

# %%
book_df.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'series', 'country_code', 'language_code',
#        'popular_shelves', 'asin', 'is_ebook', 'average_rating', 'kindle_asin',
#        'similar_books', 'description', 'format', 'link', 'authors',
#        'publisher', 'num_pages', 'publication_day', 'isbn13',
#        'publication_month', 'edition_information', 'publication_year', 'url',
#        'image_url', 'book_id', 'ratings_count', 'work_id', 'title',
#        'title_without_series'],
#       dtype='object')

# %%
book_df['processed_description'] = book_df['description'].apply(lambda x: preprocess(x))
book_df['processed_description'] = book_df['processed_description'].apply(lambda x: lemmas(x, lm))
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
book_df.head()
# Out:
#          isbn  text_reviews_count                                    series  \
# 0  1401207928                3400                                ['631559']
# 1   394541553                4402                                ['186595']
# 2  1401207529                1790  ['482441', '300099', '194163', '636672']
# 3  1421501686                2399                                ['205782']
# 4  1607066017                8700                                ['736247']
#
#   country_code language_code  \
# 0           US           eng
# 1           US           eng
# 2           US           eng
# 3           US           eng
# 4           US           eng
#
#                                      popular_shelves asin  is_ebook  \
# 0  [{'count': '42534', 'name': 'to-read'}, {'coun...  NaN     False
# 1  [{'count': '92915', 'name': 'to-read'}, {'coun...  NaN     False
# 2  [{'count': '7924', 'name': 'to-read'}, {'count...  NaN     False
# 3  [{'count': '9727', 'name': 'to-read'}, {'count...  NaN     False
# 4  [{'count': '78762', 'name': 'to-read'}, {'coun...  NaN     False
#
#    average_rating kindle_asin  ... edition_information publication_year  \
# 0            4.25  B0064W65UM  ...                 NaN           2005.0
# 1            4.35         NaN  ...                 NaN           1991.0
# 2            4.22  B0064W65SO  ...                 NaN           2005.0
# 3            4.42         NaN  ...                 NaN           2005.0
# 4            4.24  B015XEABR4  ...                 NaN           2012.0
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/5805.V_for...
# 1   https://www.goodreads.com/book/show/15196.Maus_I
# 2   https://www.goodreads.com/book/show/59980.Batman
# 3  https://www.goodreads.com/book/show/13615.Deat...
# 4  https://www.goodreads.com/book/show/15704307-s...
#
#                                            image_url   book_id ratings_count  \
# 0  https://images.gr-assets.com/books/1343668985m...      5805        212464
# 1  https://images.gr-assets.com/books/1327884972m...     15196        189288
# 2  https://images.gr-assets.com/books/1327940389m...     59980        154013
# 3  https://images.gr-assets.com/books/1419952134m...     13615        142755
# 4  https://images.gr-assets.com/books/1486028947m...  15704307        142640
#
#     work_id                                              title  \
# 0    392838                                     V for Vendetta
# 1   1947012  Maus I: A Survivor's Tale: My Father Bleeds Hi...
# 2   2501570                                   Batman: Year One
# 3   1782155       Death Note, Vol. 1: Boredom (Death Note, #1)
# 4  19113524                            Saga, Vol. 1 (Saga, #1)
#
#                                 title_without_series  \
# 0                                     V for Vendetta
# 1  Maus I: A Survivor's Tale: My Father Bleeds Hi...
# 2                                   Batman: Year One
# 3       Death Note, Vol. 1: Boredom (Death Note, #1)
# 4                            Saga, Vol. 1 (Saga, #1)
#
#                                processed_description
# 0  [remember, remember, fifth, frightening, power...
# 1  [story, jewish, survivor, son, cartoonist, try...
# 2  [lieutenant, take, new, post, crime, ride, cor...
# 3  [light, ace, student, great, prospect, bore, m...
# 4  [two, soldier, opposite, side, never, end, gal...
#
# [5 rows x 30 columns]

# %%
book_df.to_csv('./data/book_p.csv', index = False)
